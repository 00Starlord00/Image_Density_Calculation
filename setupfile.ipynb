# %% [markdown]
# <a href="https://colab.research.google.com/github/00Starlord00/Image_Density_Calculation/blob/master/setupfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy
import scipy.io as io
import h5py
import glob 
import os
import cv2
import matplotlib as plt
import torch
import torchvision.transforms as transforms
import tensorflow as tf
import matplotlib.pyplot as plt

from image import *
#from model import CSRNet
from tqdm import tqdm
from scipy.ndimage.filters import gaussian_filter
from google.colab import drive
from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
def loadImages(path):
    counter  = 0
    image_files = [os.path.join(path, file) for file in os.listdir(path)]
    return image_files

path = '/content/drive/My Drive/Colab Notebooks/Train_dataset/images'
dataset = loadImages(path)
print(len(dataset))
# Out:
# 6484

# %%
for img in dataset:
    plt.imshow(cv2.imread(img))
    plt.show()

# %%
train_path = '/content/drive/My Drive/Colab Notebooks/Train_dataset/images'
valid_path = '/content/drive/My Drive/Colab Notebooks/Val_dataset/images'
test_path = '/content/drive/My Drive/Colab Notebooks/Test_dataset/images'
